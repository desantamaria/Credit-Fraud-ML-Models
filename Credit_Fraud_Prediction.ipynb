# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('fraudTrain.csv')

# %%
df
# Out:
#            index trans_date_trans_time               cc_num  \
# 0              0   2019-01-01 00:00:18     2703186189652095
# 1              1   2019-01-01 00:00:44         630423337322
# 2              2   2019-01-01 00:00:51       38859492057661
# 3              3   2019-01-01 00:01:16     3534093764340240
# 4              4   2019-01-01 00:03:06      375534208663984
# ...          ...                   ...                  ...
# 1296670  1296670   2020-06-21 12:12:08       30263540414123
# 1296671  1296671   2020-06-21 12:12:19     6011149206456997
# 1296672  1296672   2020-06-21 12:12:32     3514865930894695
# 1296673  1296673   2020-06-21 12:13:36     2720012583106919
# 1296674  1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
df.describe()
# Out:
#               index        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12, 10))

# %%
sns.countplot(x='is_fraud', data=df)
plt.title('Distribution of Fraudulent')
# Out:
# Text(0.5, 1.0, 'Distribution of Fraudulent')

# %%
sns.histplot(x='amt', data=df, kde=True)
plt.title('Distribution of Transaction Amount')
# Out:
# Text(0.5, 1.0, 'Distribution of Transaction Amount')

# %%
sns.histplot(x='gender', data=df, kde=True)
plt.title('Distribution of Transaction Amount')
# Out:
# Text(0.5, 1.0, 'Distribution of Transaction Amount')

# %%
sns.scatterplot(x='amt', y='category', data=df, hue='is_fraud')
plt.title('Transaction Amount vs Category')
# Out:
# Text(0.5, 1.0, 'Transaction Amount vs Category')

# %%
sns.scatterplot(x='zip', y='category', data=df, hue='is_fraud')
plt.title('Transaction Amount vs Category')
# Out:
# Text(0.5, 1.0, 'Transaction Amount vs Category')
# /opt/miniconda3/envs/sklearn-env/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /opt/miniconda3/envs/sklearn-env/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(x='zip', y='city_pop', data=df, hue='is_fraud')
# Out:
# <Axes: xlabel='zip', ylabel='city_pop'>

# %%
sns.scatterplot(x='merch_long', y='merch_lat', data=df, hue='is_fraud')
plt.title('Merchant Longitude vs Latitude')
# Out:
# Text(0.5, 1.0, 'Merchant Longitude vs Latitude')

# %%
features = df.drop(columns=['is_fraud', 'trans_num', 'index', 'job', 'cc_num', 'merchant', 'first', 'last','street', 'city', 'state', 'city_pop', 'dob', 'trans_date_trans_time'])
features
# Out:
#               category     amt gender    zip      lat      long   unix_time  \
# 0             misc_net    4.97      F  28654  36.0788  -81.1781  1325376018
# 1          grocery_pos  107.23      F  99160  48.8878 -118.2105  1325376044
# 2        entertainment  220.11      M  83252  42.1808 -112.2620  1325376051
# 3        gas_transport   45.00      M  59632  46.2306 -112.1138  1325376076
# 4             misc_pos   41.96      M  24433  38.4207  -79.4629  1325376186
# ...                ...     ...    ...    ...      ...       ...         ...
# 1296670  entertainment   15.56      M  84735  37.7175 -112.4777  1371816728
# 1296671    food_dining   51.70      M  21790  39.2667  -77.5101  1371816739
# 1296672    food_dining  105.93      M  88325  32.9396 -105.8189  1371816752
# 1296673    food_dining   74.90      M  57756  43.3526 -102.5411  1371816816
# 1296674    food_dining    4.30      M  59871  45.8433 -113.8748  1371816817
#
#          merch_lat  merch_long
# ...

# %%
features.columns
# Out:
# Index(['category', 'amt', 'gender', 'zip', 'lat', 'long', 'unix_time',
#        'merch_lat', 'merch_long'],
#       dtype='object')

# %%
features = pd.get_dummies(features, drop_first=True, columns=['gender', 'category'])
features.columns
# Out:
# Index(['amt', 'zip', 'lat', 'long', 'unix_time', 'merch_lat', 'merch_long',
#        'gender_M', 'category_food_dining', 'category_gas_transport',
#        'category_grocery_net', 'category_grocery_pos',
#        'category_health_fitness', 'category_home', 'category_kids_pets',
#        'category_misc_net', 'category_misc_pos', 'category_personal_care',
#        'category_shopping_net', 'category_shopping_pos', 'category_travel'],
#       dtype='object')

# %%
features
# Out:
#             amt    zip      lat      long   unix_time  merch_lat  merch_long  \
# 0          4.97  28654  36.0788  -81.1781  1325376018  36.011293  -82.048315
# 1        107.23  99160  48.8878 -118.2105  1325376044  49.159047 -118.186462
# 2        220.11  83252  42.1808 -112.2620  1325376051  43.150704 -112.154481
# 3         45.00  59632  46.2306 -112.1138  1325376076  47.034331 -112.561071
# 4         41.96  24433  38.4207  -79.4629  1325376186  38.674999  -78.632459
# ...         ...    ...      ...       ...         ...        ...         ...
# 1296670   15.56  84735  37.7175 -112.4777  1371816728  36.841266 -111.690765
# 1296671   51.70  21790  39.2667  -77.5101  1371816739  38.906881  -78.246528
# 1296672  105.93  88325  32.9396 -105.8189  1371816752  33.619513 -105.130529
# 1296673   74.90  57756  43.3526 -102.5411  1371816816  42.788940 -103.241160
# 1296674    4.30  59871  45.8433 -113.8748  1371816817  46.565983 -114.186110
#
# ...

# %%
target = df['is_fraud']
target
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1296670    0
# 1296671    0
# 1296672    0
# 1296673    0
# 1296674    0
# Name: is_fraud, Length: 1296675, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train[0]
# Out:
# array([-0.40300154,  0.81570055, -1.55255482, -0.10208397, -0.79742859,
#        -1.4380815 , -0.08744271, -0.90848332, -0.27544534, -0.33616994,
#        -0.19026073, -0.32477796, -0.26634085, -0.32384126, -0.30898036,
#        -0.22656136, -0.25617995, -0.27442719, -0.28515177, -0.31460093,
#         5.56739873])

# %%
X_train[1]
# Out:
# array([-0.3167202 ,  1.83874567,  1.93108458, -2.335859  ,  0.41484723,
#         1.72920458, -2.36236846, -0.90848332, -0.27544534, -0.33616994,
#        -0.19026073, -0.32477796, -0.26634085, -0.32384126, -0.30898036,
#        -0.22656136, -0.25617995, -0.27442719, -0.28515177, -0.31460093,
#        -0.1796171 ])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
lr_model = LogisticRegression(random_state=42)

# %%
lr_model.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)

# %%
lr_predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lr_accuracy = accuracy_score(y_test,lr_predictions)

# %%
lr_accuracy
# Out:
# 0.9935990128598146

# %%
def evaluate_and_save_model(model, X_train, X_test, y_train, y_test, filename):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model.__class__.__name__} Accuracy: {accuracy:.4f}")
    print(f"\nClassification Report:\n{classification_report(y_test, y_pred)}")
    print("-----------")
    with open(filename, 'wb') as file:
        pickle.dump(model, file)

    print(f"Model saved as {filename}")

# %%
xgb_model = xgb.XGBClassifier(random_state=42, colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0)
evaluate_and_save_model(xgb_model, X_train, X_test, y_train, y_test, 'xgb_model.pkl')

dt_model = DecisionTreeClassifier(random_state=42, criterion='entropy', max_depth= 5, min_samples_leaf=4, min_samples_split=10)
evaluate_and_save_model(dt_model, X_train, X_test, y_train, y_test, 'dt_model.pkl')

rf_model = RandomForestClassifier(random_state=42, bootstrap=False, max_depth= None, min_samples_leaf=2, min_samples_split=10, n_estimators=50)
evaluate_and_save_model(rf_model, X_train, X_test, y_train, y_test, 'rf_model.pkl')

et_model = ExtraTreesClassifier(random_state=42, bootstrap=False, max_depth= None, min_samples_leaf=2, min_samples_split=10, n_estimators=50)
evaluate_and_save_model(et_model, X_train, X_test, y_train, y_test, 'et_model.pkl')

nb_model = GaussianNB(var_smoothing=1e-09)
evaluate_and_save_model(nb_model, X_train, X_test, y_train, y_test, 'nb_model.pkl')

knn_model = KNeighborsClassifier(metric='euclidean', n_neighbors=3, weights='distance')
evaluate_and_save_model(knn_model, X_train, X_test, y_train, y_test, 'knn_model.pkl')
# Out:
# XGBClassifier Accuracy: 0.9971
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    257815
#            1       0.85      0.61      0.71      1520
#
#     accuracy                           1.00    259335
#    macro avg       0.92      0.80      0.85    259335
# weighted avg       1.00      1.00      1.00    259335
#
# -----------
# Model saved as xgb_model.pkl
# DecisionTreeClassifier Accuracy: 0.9959
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    257815
#            1       0.98      0.30      0.46      1520
#
#     accuracy                           1.00    259335
#    macro avg       0.99      0.65      0.73    259335
# weighted avg       1.00      1.00      0.99    259335
#
# -----------
# Model saved as dt_model.pkl
# RandomForestClassifier Accuracy: 0.9973
#
# Classification Report:
# ...

# %%
features_importances = rf_model.feature_importances_
features_names = features.columns

# %%
features_importances
# Out:
# array([6.08466110e-01, 3.09510789e-02, 3.27254366e-02, 3.22136169e-02,
#        4.93653397e-02, 3.68729761e-02, 3.66537786e-02, 1.00144503e-02,
#        5.11559992e-04, 2.21483730e-02, 7.17203252e-04, 8.75722517e-02,
#        6.79589224e-04, 2.08982895e-03, 9.57362569e-04, 7.44897836e-03,
#        1.23015848e-02, 7.80021328e-04, 1.35330007e-02, 6.30657518e-03,
#        7.69088383e-03])

# %%
features_importances_df = pd.DataFrame({'feature': features_names, 'importance': features_importances})

# %%
features_importances_df
# Out:
#                     feature  importance
# 0                       amt    0.608466
# 1                       zip    0.030951
# 2                       lat    0.032725
# 3                      long    0.032214
# 4                 unix_time    0.049365
# 5                 merch_lat    0.036873
# 6                merch_long    0.036654
# 7                  gender_M    0.010014
# 8      category_food_dining    0.000512
# 9    category_gas_transport    0.022148
# 10     category_grocery_net    0.000717
# 11     category_grocery_pos    0.087572
# 12  category_health_fitness    0.000680
# 13            category_home    0.002090
# 14       category_kids_pets    0.000957
# 15        category_misc_net    0.007449
# 16        category_misc_pos    0.012302
# 17   category_personal_care    0.000780
# 18    category_shopping_net    0.013533
# 19    category_shopping_pos    0.006307
# 20          category_travel    0.007691

# %%
features_importances_df = features_importances_df.sort_values(by='importance', ascending=False)

# %%
features_importances_df
# Out:
#                     feature  importance
# 0                       amt    0.608466
# 11     category_grocery_pos    0.087572
# 4                 unix_time    0.049365
# 5                 merch_lat    0.036873
# 6                merch_long    0.036654
# 2                       lat    0.032725
# 3                      long    0.032214
# 1                       zip    0.030951
# 9    category_gas_transport    0.022148
# 18    category_shopping_net    0.013533
# 16        category_misc_pos    0.012302
# 7                  gender_M    0.010014
# 20          category_travel    0.007691
# 15        category_misc_net    0.007449
# 19    category_shopping_pos    0.006307
# 13            category_home    0.002090
# 14       category_kids_pets    0.000957
# 17   category_personal_care    0.000780
# 10     category_grocery_net    0.000717
# 12  category_health_fitness    0.000680
# 8      category_food_dining    0.000512

# %%
plt.figure(figsize=(10, 6))
plt.bar(features_importances_df['feature'], features_importances_df['importance'])
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.tight_layout()
plt.show()

# %%
features
# Out:
#             amt    zip      lat      long   unix_time  merch_lat  merch_long  \
# 0          4.97  28654  36.0788  -81.1781  1325376018  36.011293  -82.048315
# 1        107.23  99160  48.8878 -118.2105  1325376044  49.159047 -118.186462
# 2        220.11  83252  42.1808 -112.2620  1325376051  43.150704 -112.154481
# 3         45.00  59632  46.2306 -112.1138  1325376076  47.034331 -112.561071
# 4         41.96  24433  38.4207  -79.4629  1325376186  38.674999  -78.632459
# ...         ...    ...      ...       ...         ...        ...         ...
# 1296670   15.56  84735  37.7175 -112.4777  1371816728  36.841266 -111.690765
# 1296671   51.70  21790  39.2667  -77.5101  1371816739  38.906881  -78.246528
# 1296672  105.93  88325  32.9396 -105.8189  1371816752  33.619513 -105.130529
# 1296673   74.90  57756  43.3526 -102.5411  1371816816  42.788940 -103.241160
# 1296674    4.30  59871  45.8433 -113.8748  1371816817  46.565983 -114.186110
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#             amt    zip      lat      long   unix_time  merch_lat  merch_long  \
# 330201     6.51  70732  30.6576  -91.6264  1338993811  31.189017  -91.426377
# 798518    20.17  98238  48.3400 -122.3456  1354562808  47.373663 -122.739095
# 1260375   35.85  75662  32.3836  -94.8653  1370692963  31.989881  -95.371119
# 412511    42.21  49621  44.8605  -85.8138  1341539214  45.377530  -86.450595
# 344644    57.24  60432  41.5378  -88.0572  1339371240  42.372906  -87.112752
# ...         ...    ...      ...       ...         ...        ...         ...
# 110268    72.38  54896  45.8327  -91.0144  1330829368  45.043710  -90.231846
# 259178     2.33   6441  41.4682  -72.5751  1336546444  40.711495  -71.670634
# 131932   118.27  87117  35.0203 -106.5503  1331675187  34.849069 -106.219762
# 671155     5.60  56729  48.6669  -96.5969  1350120506  47.807830  -97.498754
# 121958   140.73  29320  34.9572  -81.9916  1331316795  34.989024  -82.842443
#
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
evaluate_and_save_model(xgb_model, X_resampled, X_test, y_resampled, y_test, "xgboost-SMOTE.pkl")
evaluate_and_save_model(dt_model, X_resampled, X_test, y_resampled, y_test, "decision-tree-SMOTE.pkl")
evaluate_and_save_model(rf_model, X_resampled, X_test, y_resampled, y_test, "random-forest-SMOTE.pkl")
evaluate_and_save_model(et_model, X_resampled, X_test, y_resampled, y_test, "extra-trees-SMOTE.pkl")
evaluate_and_save_model(nb_model, X_resampled, X_test, y_resampled, y_test, "naive-bayes-SMOTE.pkl")
evaluate_and_save_model(knn_model, X_resampled, X_test, y_resampled, y_test, "knn-SMOTE.pkl")
# Out:
# XGBClassifier Accuracy: 0.9887
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    257815
#            1       0.32      0.83      0.46      1520
#
#     accuracy                           0.99    259335
#    macro avg       0.66      0.91      0.73    259335
# weighted avg       0.99      0.99      0.99    259335
#
# -----------
# Model saved as xgboost-SMOTE.pkl
# DecisionTreeClassifier Accuracy: 0.9648
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98    257815
#            1       0.13      0.86      0.22      1520
#
#     accuracy                           0.96    259335
#    macro avg       0.56      0.91      0.60    259335
# weighted avg       0.99      0.96      0.98    259335
#
# -----------
# Model saved as decision-tree-SMOTE.pkl
# RandomForestClassifier Accuracy: 0.9962
#
# Classification Report:
# ...

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(estimators=[('xgboost', xgb.XGBClassifier(random_state=42,colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0)), ('rf', RandomForestClassifier(random_state=42)), ('svm', SVC(random_state=42, probability=True))], voting='hard')
